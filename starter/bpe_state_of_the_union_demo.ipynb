# %% [markdown]
# # AIG 230 – BPE Demo Notebook
# ## Byte Pair Encoding (BPE) with the State of the Union Corpus
#
# **Purpose of this notebook**
# This notebook demonstrates, end-to-end, how **Byte Pair Encoding (BPE)** works using a *real corpus*: the U.S. State of the Union addresses.
#
# This notebook is intentionally simple and conceptual. It exists to build correct mental models about subword tokenization.

# %% [markdown]
# ## 1. Setup
#
# We use:
# - NLTK to access the State of the Union corpus
# - Hugging Face `tokenizers` to train a simple BPE tokenizer

# %%
# Install if needed
# !pip install nltk tokenizers

import nltk
from nltk.corpus import state_union

nltk.download("state_union", quiet=True)
# Out:
# True

# %% [markdown]
# ## 2. Load and Inspect the Corpus

# %%
fileids = state_union.fileids()
len(fileids), fileids[:5]
# Out:
# (65,
#  ['1945-Truman.txt',
#   '1946-Truman.txt',
#   '1947-Truman.txt',
#   '1948-Truman.txt',
#   '1949-Truman.txt'])

# %%
texts = [state_union.raw(fid) for fid in fileids[:10]]
corpus_text = "\n".join(texts)

corpus_text[:500]
# Out:
# "PRESIDENT HARRY S. TRUMAN'S ADDRESS BEFORE A JOINT SESSION OF THE CONGRESS\n \nApril 16, 1945\n\nMr. Speaker, Mr. President, Members of the Congress:\nIt is with a heavy heart that I stand before you, my friends and colleagues, in the Congress of the United States.\nOnly yesterday, we laid to rest the mortal remains of our beloved President, Franklin Delano Roosevelt. At a time like this, words are inadequate. The most eloquent tribute would be a reverent silence.\nYet, in this decisive hour, when worl"

# %% [markdown]
# ## 3. Why BPE?
#
# BPE learns **subword units** from data instead of relying on predefined words.

# %% [markdown]
# ## 4. Train a Simple BPE Tokenizer

# %%
# !pip install tokenizers
# Out:
# Collecting tokenizers
#   Downloading tokenizers-0.22.2-cp39-abi3-macosx_10_12_x86_64.whl.metadata (7.3 kB)
# Collecting huggingface-hub<2.0,>=0.16.4 (from tokenizers)
#   Downloading huggingface_hub-1.3.2-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Using cached filelock-3.20.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Using cached fsspec-2026.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading hf_xet-1.2.0-cp37-abi3-macosx_10_12_x86_64.whl.metadata (4.9 kB)
# Collecting httpx<1,>=0.23.0 (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/envs/aig230-env/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (25.0)
# Collecting pyyaml>=5.1 (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading pyyaml-6.0.3-cp311-cp311-macosx_10_13_x86_64.whl.metadata (2.4 kB)
# Collecting shellingham (from huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/envs/aig230-env/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.67.1)
# Requirement already satisfied: typer-slim in /opt/anaconda3/envs/aig230-env/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /opt/anaconda3/envs/aig230-env/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers) (4.15.0)
# Collecting anyio (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/aig230-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (2026.1.4)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /opt/anaconda3/envs/aig230-env/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers) (3.11)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/envs/aig230-env/lib/python3.11/site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers) (8.3.1)
# Downloading tokenizers-0.22.2-cp39-abi3-macosx_10_12_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.2 MB/s  0:00:00
# Downloading huggingface_hub-1.3.2-py3-none-any.whl (534 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 534.5/534.5 kB 25.4 MB/s  0:00:00
# Downloading hf_xet-1.2.0-cp37-abi3-macosx_10_12_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 28.3 MB/s  0:00:00
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached fsspec-2026.1.0-py3-none-any.whl (201 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading pyyaml-6.0.3-cp311-cp311-macosx_10_13_x86_64.whl (185 kB)
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
# Using cached filelock-3.20.3-py3-none-any.whl (16 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: shellingham, pyyaml, hf-xet, h11, fsspec, filelock, anyio, httpcore, httpx, huggingface-hub, tokenizers
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [tokenizers]1 [huggingface-hub]
# Successfully installed anyio-4.12.1 filelock-3.20.3 fsspec-2026.1.0 h11-0.16.0 hf-xet-1.2.0 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-1.3.2 pyyaml-6.0.3 shellingham-1.5.4 tokenizers-0.22.2

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE
from tokenizers.trainers import BpeTrainer
from tokenizers.pre_tokenizers import Whitespace

tokenizer = Tokenizer(BPE(unk_token="[UNK]"))
tokenizer.pre_tokenizer = Whitespace()

trainer = BpeTrainer(
    vocab_size=200,
    special_tokens=["[UNK]", "[PAD]", "[CLS]", "[SEP]", "[MASK]"]
)

tokenizer.train_from_iterator([corpus_text], trainer=trainer)

# %% [markdown]
# ## 5. Inspect the Learned Vocabulary

# %%
vocab = tokenizer.get_vocab()
list(vocab.items())[:30]
# Out:
# [('ce', 144),
#  ('7', 23),
#  ('ow', 143),
#  ('K', 39),
#  ('(', 10),
#  ('ab', 155),
#  ('th', 84),
#  ('am', 153),
#  ('U', 49),
#  ('that', 137),
#  ('ir', 163),
#  ('em', 181),
#  ('[SEP]', 3),
#  ('ha', 146),
#  ('2', 18),
#  ('pro', 116),
#  ('z', 81),
#  ('d', 59),
#  ('are', 134),
#  ('j', 65),
#  ('M', 41),
#  ('The', 152),
#  ('ear', 168),
#  ('over', 167),
#  ('for', 117),
#  ('en', 91),
#  ('end', 145),
#  ('ve', 112),
#  ('I', 37),
#  ('W', 51)]

# %% [markdown]
# ## 6. BPE Tokenization Example

# %%
sentence = "Democracy and democratic institutions must be protected."
tokenizer.encode(sentence).tokens
# Out:
# ['D',
#  'e',
#  'mo',
#  'c',
#  'r',
#  'ac',
#  'y',
#  'and',
#  'de',
#  'mo',
#  'c',
#  'r',
#  'at',
#  'ic',
#  'in',
#  'st',
#  'it',
#  'u',
#  'tion',
#  's',
#  'm',
#  'ust',
#  'be',
#  'pro',
#  't',
#  'ec',
#  't',
#  'ed',
#  '.']

# %% [markdown]
# ## 7. Key Takeaways
#
# - BPE tokenization is **learned from data**
# - It captures shared structure across related words
# - It is used by modern language models
# - It is intentionally outside NLTK and spaCy

# %% [markdown]
# Different purpose: Classical NLP vs LLMs
# | Library                      | Main goal                     | Tokenization type              |
# | ---------------------------- | ----------------------------- | ------------------------------ |
# | **NLTK**                     | linguistics + traditional NLP | word / sentence tokenization   |
# | **spaCy**                    | production NLP pipelines      | rule-based word tokenization   |
# | **BPE (Byte Pair Encoding)** | ML model input efficiency     | subword tokens for neural nets |
